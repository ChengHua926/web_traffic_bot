# %%
from urllib import request
from random import randint

url = "https://huacheng615.wixsite.com/my-site-1"

n = 1000

proxy = [{'https': '110.88.10.198'}, {'https': '182.88.117.118'}, {'https': '180.158.109.60'},
         {'https': '110.88.10.198'}, {'https': '122.235.184.109'}, {'https': '221.3.39.207'}]

for _ in range(n):
    proxy_support = request.ProxyHandler(proxy[randint(0, len(proxy)-1)])
    opener = request.build_opener(proxy_support)
    opener.addheaders = [('User-Agent',
                          'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36')]
    request.install_opener(opener)
    response = request.urlopen(url)
    print((_ + 1) / n)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:975, in HTTPConnection.send(self, data)
#     974 if self.auto_open:
# --> 975     self.connect()
#     976 else:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:1447, in HTTPSConnection.connect(self)
#    1445 "Connect to a host on a given (SSL) port."
# -> 1447 super().connect()
#    1449 if self._tunnel_host:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:941, in HTTPConnection.connect(self)
#     940 sys.audit("http.client.connect", self, self.host, self.port)
# --> 941 self.sock = self._create_connection(
#     942     (self.host,self.port), self.timeout, self.source_address)
#     943 # Might fail in OSs that don't implement TCP_NODELAY
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\socket.py:845, in create_connection(address, timeout, source_address)
#     844 try:
# --> 845     raise err
#     846 finally:
#     847     # Break explicitly a reference cycle
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\socket.py:833, in create_connection(address, timeout, source_address)
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[1], line 17
#      14 opener.addheaders = [('User-Agent',
#      15                       'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36')]
#      16 request.install_opener(opener)
# ---> 17 response = request.urlopen(url)
#      18 print((_ + 1) / n)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>

# %%
import requests
import time
url = ['https://huacheng615.wixsite.com/my-site-1']
# 浏览器User-Agent 
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'}   
count = 0
countUrl = len(url)
# 访问次数设置
for i in range(1,1000):
    if count < 10000:
        try:  # 正常运行
            for i in range(countUrl):
                response = requests.get(url[i], headers=headers)
                if response.status_code == 200:
                    count = count + 1
                    print('Success ' + str(count), 'times')    
                    print(count)
            time.sleep(60) # 访问间隔时间秒
        except Exception:  # 异常
            print('Failed and Retry')
            print(Exception)
            time.sleep(60) # 异常重启时间秒
# Out:
# Success 1 times
# 1
# Success 2 times
# 2
# Success 3 times
# 3
# Success 4 times
# 4
# Success 5 times
# 5
# Success 6 times
# 6
# Success 7 times
# 7
# Success 8 times
# 8
# Success 9 times
# 9
# Success 10 times
# 10
# Success 11 times
# 11
# Success 12 times
# 12
# Success 13 times
# 13
# Success 14 times
# 14
# Success 15 times
# 15
# Success 16 times
# 16
# Success 17 times
# 17
# Success 18 times
# 18
# Success 19 times
# 19
# Success 20 times
# 20
# Success 21 times
# 21
# Success 22 times
# 22
# Success 23 times
# 23
# Success 24 times
# 24
# Success 25 times
# 25
# Success 26 times
# 26
# Success 27 times
# 27
# Success 28 times
# 28
# Success 29 times
# 29
# Success 30 times
# 30
# Success 31 times
# 31
# Success 32 times
# 32
# Success 33 times
# 33
# Success 34 times
# 34
# Success 35 times
# 35
# Success 36 times
# 36
# Success 37 times
# 37
# Success 38 times
# 38
# Success 39 times
# 39
# Success 40 times
# 40
# Success 41 times
# 41
# Success 42 times
# 42
# Success 43 times
# 43
# Success 44 times
# 44
# Success 45 times
# 45
# Success 46 times
# 46
# Success 47 times
# 47
# Success 48 times
# 48
# Success 49 times
# 49
# Success 50 times
# 50
# Success 51 times
# 51
# Success 52 times
# 52
# Success 53 times
# 53
# Success 54 times
# 54
# Success 55 times
# 55
# Success 56 times
# 56
# Success 57 times
# 57
# Success 58 times
# 58
# Success 59 times
# 59
# Success 60 times
# 60
# Success 61 times
# 61
# Success 62 times
# 62
# Success 63 times
# 63
# Success 64 times
# 64
# Success 65 times
# 65
# Success 66 times
# 66
# Success 67 times
# 67
# Success 68 times
# 68
# Success 69 times
# 69
# Success 70 times
# 70
# Success 71 times
# 71
# Success 72 times
# 72
# Success 73 times
# 73
# Success 74 times
# 74
# Success 75 times
# 75
# Success 76 times
# 76
# Success 77 times
# 77
# Success 78 times
# 78
# Success 79 times
# 79
# Success 80 times
# 80
# Success 81 times
# 81
# Success 82 times
# 82
# Success 83 times
# 83
# Success 84 times
# 84
# Success 85 times
# 85
# Failed and Retry
# <class 'Exception'>
# Failed and Retry
# <class 'Exception'>
# Success 86 times
# 86
# Success 87 times
# 87
# Success 88 times
# 88
# Success 89 times
# 89
# Success 90 times
# 90
# Success 91 times
# 91
# Success 92 times
# 92
# Success 93 times
# 93
# Success 94 times
# 94
# Success 95 times
# 95
# Success 96 times
# 96
# Success 97 times
# 97
# Success 98 times
# 98
# Success 99 times
# 99
# Success 100 times
# 100
# Success 101 times
# 101
# Success 102 times
# 102
# Success 103 times
# 103
# Success 104 times
# 104
# Success 105 times
# 105
# Success 106 times
# 106
# Success 107 times
# 107
# Success 108 times
# 108
# Success 109 times
# 109
# Success 110 times
# 110
# Success 111 times
# 111
# Success 112 times
# 112
# Success 113 times
# 113
# Success 114 times
# 114
# Success 115 times
# 115
# Success 116 times
# 116
# Success 117 times
# 117
# Success 118 times
# Success 241 times
# 241
# Success 242 times
# 242
# Success 243 times
# 243
# Success 244 times
# 244
# Success 245 times
# 245
# Success 246 times
# 246
# Success 247 times
# 247
# Success 248 times
# 248
# Success 249 times
# 249
# Success 250 times
# 250
# Success 251 times
# 251
# Success 252 times
# 252
# Success 253 times
# 253
# Success 254 times
# 254
# Success 255 times
# 255
# Success 256 times
# 256
# Success 257 times
# 257
# Success 258 times
# 258
# Success 259 times
# 259
# Success 260 times
# 260
# Success 261 times
# 261
# Success 262 times
# 262
# Success 263 times
# 263
# Success 264 times
# 264
# Success 265 times
# 265
# Success 266 times
# 266
# Success 267 times
# 267
# Success 268 times
# 268
# Success 269 times
# 269
# Success 270 times
# 270
# Success 271 times
# 271
# Success 272 times
# 272
# Success 273 times
# 273
# Success 274 times
# 274
# Success 275 times
# 275
# Success 276 times
# 276
# Success 277 times
# 277
# Success 278 times
# 278
# Success 279 times
# 279
# Success 280 times
# 280
# Success 281 times
# 281
# Success 282 times
# 282
# Success 283 times
# 283
# Success 284 times
# 284
# Success 285 times
# 285
# Success 286 times
# 286
# Success 287 times
# 287
# Success 288 times
# 288
# Success 289 times
# 289
# Success 290 times
# 290
# Success 291 times
# 291
# Success 292 times
# 292
# Success 293 times
# 293
# Success 294 times
# 294
# Success 295 times
# 295
# Success 296 times
# 296
# Success 297 times
# 297
# Success 298 times
# 298
# Success 299 times
# 299
# Success 300 times
# 300
# Success 301 times
# 301
# Success 302 times
# 302
# Success 303 times
# 303
# Success 304 times
# 304
# Success 305 times
# 305
# Success 306 times
# 306
# Success 307 times
# 307
# Success 308 times
# 308
# Success 309 times
# 309
# Success 310 times
# 310
# Success 311 times
# 311
# Success 312 times
# 312
# Success 313 times
# 313
# Success 314 times
# 314
# Success 315 times
# 315
# Success 316 times
# 316
# Success 317 times
# 317
# Success 318 times
# 318
# Success 319 times
# 319
# Success 320 times
# 320
# Success 321 times
# 321
# Success 322 times
# 322
# Success 323 times
# 323
# Success 324 times
# 324
# Success 325 times
# 325
# Success 326 times
# 326
# Success 327 times
# 327
# Success 328 times
# 328
# Success 329 times
# 329
# Success 330 times
# 330
# Success 331 times
# 331
# Success 332 times
# 332
# Success 333 times
# 333
# Success 334 times
# 334
# Success 335 times
# 335
# Success 336 times
# 336
# Success 337 times
# 337
# Success 338 times
# 338
# Success 339 times
# 339
# Success 340 times
# 340
# Success 341 times
# 341
# Success 342 times
# 342
# Success 343 times
# 343
# Success 344 times
# 344
# Success 345 times
# 345
# Success 346 times
# 346
# Success 347 times
# 347
# Success 348 times
# 348
# Success 349 times
# 349
# Success 350 times
# 350
# Success 351 times
# 351
# Success 352 times
# 352
# Success 353 times
# 353
# Success 354 times
# 354
# Success 355 times
# 355
# Success 356 times
# 356
# Success 357 times
# 357
# Success 358 times
# 358
# Success 359 times
# 359
# Success 360 times
# 360
# Success 361 times
# 361
# Success 362 times
# 362
